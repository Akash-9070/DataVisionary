# %% [markdown]
# # PLotly and Cufflinks

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pip install cufflinks
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

df = pd.read_csv('E:\\archive (1)\\TITAN.csv')

fig = go.Figure(data=[go.Candlestick(x=df['Date'][:30],
                open=df['Open'][:30],
                high=df['High'][:30],
                low=df['Low'],
                close=df['Close'][:30])])

fig.show()
# Out:
# <div>                            <div id="02448a46-a9a1-424b-b7f1-0905516c78d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02448a46-a9a1-424b-b7f1-0905516c78d9")) {                    Plotly.newPlot(                        "02448a46-a9a1-424b-b7f1-0905516c78d9",                        [{"close":[155.7,147.4,138.4,149.5,146.35,144.9,141.0,147.9,148.85,144.5,143.75,139.2,142.15,141.1,138.85,140.05,137.7,138.7,136.2,136.05,134.75,129.1,125.55,123.7,114.0,118.1,117.5,117.1,108.7,102.05],"high":[156.45,152.0,148.8,149.5,153.0,150.0,146.7,152.3,157.0,150.0,150.5,144.8,145.0,142.5,140.95,143.0,140.4,144.9,138.0,137.9,143.85,136.95,129.5,128.7,127.0,120.0,123.4,120.9,116.0,106.95],"low":[146.0,144.0,136.0,141.0,145.0,141.05,137.1,145.5,146.3,143.05,141
# ...

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# data

df = pd.DataFrame(np.random.randn(100,4),columns="A B C D".split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.941834 -1.239025  0.371769  2.048517
# 1 -0.040446  0.950972  0.693725  0.407075
# 2 -0.653689  1.812639 -0.467321 -1.621814
# 3  0.464565 -0.421378  1.359157 -0.530379
# 4 -0.047969 -0.342204 -1.216141 -0.296458

# %%
df2 = pd.DataFrame({"categories":["A","B","C"], "values":[23,43,45]})

# %%
df2
# Out:
#   categories  values
# 0          A      23
# 1          B      43
# 2          C      45

# %%
pip install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iplot()
# Out:
# <div>                            <div id="8a1884b3-03a8-4ea3-9e44-bddd6abe33cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="scatter",x="A",y="B",mode = "markers",size=20)
# Out:
# <div>                            <div id="e3f05d76-af83-41f6-997e-0110350ed8c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.iplot(kind="bar",x="categories",y="values")
# Out:
# <div>                            <div id="5eae97a2-4b06-4300-9c78-11e41e8211d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.sum().iplot(kind="bar")
# Out:
# <div>                            <div id="26899ceb-00c8-4538-8de4-1c37b6782786" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.454562  1.071473 -0.828249  0.172451
# 1 -0.136876  0.813073 -0.923368 -0.845173
# 2  0.143482  0.393065  0.869975 -0.521547
# 3 -0.839944  0.105396 -1.181474 -0.267321
# 4 -1.212181  1.758045  0.602611 -1.166573

# %%
df.iplot("box")
# Out:
# <div>                            <div id="33654197-52d2-4c1b-aafb-c03cc8955926" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({"x":[1,2,3,4,5],"y":[10,20,30,40,50],"z":[5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  40  2
# 4  5  50  1

# %%
df3.iplot(kind="surface",colorscale="rdylbu")# uses different kind of the colorscaling argument
# Out:
# <div>                            <div id="4e975db6-67d5-4168-98ad-0cd303c3badc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#  this how to plot a histogram plot 
df["A"].iplot(kind="hist",bins=50)
# Out:
# <div>                            <div id="1ec76ea9-5dd4-4950-ae2a-0608e493d915" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="hist")
# Out:
# <div>                            <div id="137dfb25-ee5e-4388-9b02-fe87123ea69e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[["A","B"]].head()
# Out:
#           A         B
# 0  0.454562  1.071473
# 1 -0.136876  0.813073
# 2  0.143482  0.393065
# 3 -0.839944  0.105396
# 4 -1.212181  1.758045

# %%
df[["A","B"]].iplot(kind="spread")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df[["A","B"]].iplot(kind="spread")
#
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:849, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     847 if kind=='spread':
#     848 	trace=self.apply(lambda x:x[0]-x[1],axis=1)
# ...

# %%
df.iplot(kind="bubble",x="A",y="B",size="C",color="red")
# Out:
# <div>                            <div id="e11ceca7-a06b-414b-a59c-e93b747a0155" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="3e668e00-e23e-43b2-9d76-535e21036c47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
